# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ggsri123/linux-logs")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Admin\.cache\kagglehub\datasets\ggsri123\linux-logs\versions\1

# %%
# Method to import the dataset without using download option in the kaggle
